# %%
import pandas as pd
import numpy as np
import random as rn

# %%
deld = pd.read_csv("/content/drive/MyDrive/kaggle dataset/Real estate.csv")

# %%
d = pd.DataFrame.from_records(deld)

# %%
d = d.dropna()

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
#d['X4 number of convenience stores'] = d['X4 number of convenience stores'].interpolate()
#d['X4 number of convenience stores'] = d['X4 number of convenience stores'].interpolate()


#hse_age = (hse_age - np.mean(hse_age)) / np.std(hse_age)
gn = (d['X4 number of convenience stores'], d['X2 house age'])
ng = pd.DataFrame.from_records(gn)

x = ng

#x = x / max(x)#cnv_stre = (cnv_stre - np.mean(cnv_stre)) / np.std(cnv_stre)
latt = (d['X5 latitude'] / 10000)
longt = (d['X6 longitude'] / 10000)
n = len(longt)
#d['Y house price of unit area'] = d['Y house price of unit area'].interpolate()
ghf = np.array(d['Y house price of unit area'])
y = ghf
#y = y / max(y)#y_price = ((y_price) - np.mean(y_price)) / np.std(y_price)
#y_pred = w1 * hse_age + w2 * cnv_stre + b #+ w3 * latt + w4 * longt
#/kaggle/input/real-estate-price-prediction/Real estate.csv
x = x.transpose()
y = y.transpose()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(x.shape, y.shape)
# Out:
# (414, 2) (414,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.2)
Ln = LinearRegression()
Ln.fit(x_train, y_train)
y_pred= Ln.predict(x_test)
print(y_pred)
print(y_test)
import matplotlib.pyplot as plt
plt.plot(y_pred, y_test, color = "green")
plt.show()
# Out:
# [32.69472161 44.35086577 35.28333003 39.29304531 41.73127931 48.17019698
#  29.45557423 40.77095989 23.72012001 36.46952737 33.78346901 34.46498601
#  34.46498601 54.569105   40.83291598 25.11413206 28.45524517 32.69472161
#  25.51684665 46.32894488 43.39957796 27.10124277 34.27460193 31.49560944
#  29.79633274 22.67138226 47.55063606 48.10372508 48.51095548 39.04522095
#  21.83497503 33.03999591 52.62200393 41.73127931 48.04176899 30.80506083
#  31.65049967 36.87224196 39.53635387 43.36859992 20.68878735 31.27876312
#  28.79600368 37.82352977 34.65537008 23.47229564 39.71770635 36.5669773
#  49.14343123 42.31986217 27.16319886 43.45250245 32.02223621 33.31879832
#  39.29304531 40.23530152 42.49218304 41.63834517 53.4803576  39.02715774
#  39.44793554 54.72399522 25.82662711 38.95228681 47.05047153 40.92585012
#  35.13295561 41.386005   37.95647355 28.3403646  20.78172148 24.62299913
#  34.98709698 39.65123445 58.0341303  37.2439785  35.51372376 41.48345494
# ...
